# %%
import pandas as pd
from sklearn.impute import SimpleImputer
train = pd.read_csv('train.csv')
train.head(10)

train['Cabin'] = train['Cabin'].fillna('No Cabin')
train['Embarked'] = train['Embarked'].fillna('Unknown')
# train['Age'] = train['Age'].fillna(train['Age'].mean())
train.head(10)

# Remove duplicate rows
train = train.drop_duplicates()
# Verify duplicates are removed
print(train.duplicated().sum())


num_imputer = SimpleImputer(strategy='mean')

# 2. Fit and transform the numerical column
train['Age'] = num_imputer.fit_transform(train[['Age']])
train.head(10)
# Out:
# 0
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    SibSp  Parch            Ticket     Fare     Cabin Embarked
# 0      1      0         A/5 21171   7.2500  No Cabin        S
# 1      1      0          PC 17599  71.2833       C85        C
# 2      0      0  STON/O2. 3101282   7.9250  No Cabin        S
# 3      1      0            113803  53.1000      C123        S
# 4      0      0            373450   8.0500  No Cabin        S
# 5      0      0            330877   8.4583  No Cabin        Q
# 6      0      0             17463  51.8625       E46        S
# 7      3      1            349909  21.0750  No Cabin        S
# 8      0      2            347742  11.1333  No Cabin        S
# 9      1      0            237736  30.0708  No Cabin        C
